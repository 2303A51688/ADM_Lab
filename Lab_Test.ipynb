# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51688/ADM_Lab/blob/main/Lab_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/university_student.csv")

# %%
df.head(10)
# Out:
#    Student ID  Gender Date of Birth  Study Time Grade School Type  Absences  \
# 0           1    Male    1996-12-03          11     D      Public         2
# 1           2  Female    2001-09-15           5     D     Private         0
# 2           3    Male    2002-08-09           8     A     Private         2
# 3           4    Male    1999-04-29           8     A     Private         3
# 4           5    Male    1995-06-11           9     B     Private         1
# 5           6  Female    1995-07-21          11     A     Private         1
# 6           7    Male    2000-06-04          11     C      Public         4
# 7           8    Male    1997-09-22          15     D     Private         1
# 8           9    Male    2001-05-06           8     A      Public         4
# 9          10  Female    2005-10-09          11     A     Private         5
#
#    Math Score  Reading Score  Writing Score
# 0          72             91             69
# ...

# %%
df.isna().sum()
# Out:
# Student ID       0
# Gender           0
# Date of Birth    0
# Study Time       0
# Grade            0
# School Type      0
# Absences         0
# Math Score       0
# Reading Score    0
# Writing Score    0
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
Encoder=OneHotEncoder(sparse_output=False)
df['Gender']=Encoder.fit_transform(df[['Gender']])
df['School Type']=Encoder.fit_transform(df[['School Type']])

# %%
df['Math Score'].mean()
# Out:
# 76.03

# %%
df['Math Score'].median()
# Out:
# 74.5

# %%
df['Math Score'].std()
# Out:
# 13.48134138936351

# %%
print(df.columns)
total_students_by_school_type = df.groupby('School Type')['Student ID'].count()
# Out:
# Index(['Student ID', 'Gender', 'Date of Birth', 'Study Time', 'Grade',
#        'School Type', 'Absences', 'Math Score', 'Reading Score',
#        'Writing Score'],
#       dtype='object')
